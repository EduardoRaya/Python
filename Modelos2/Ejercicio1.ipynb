# %% [markdown]
# Ejercicio 1 $\\$
# Sea $X_1,...,X_n$ una muestra aleatoria de una distribucion $F(x)$. Se define la funcion de distribucion empirica como: $\\$
# $$
# F_n(x)= \frac{1}{n} \sum^n_{i=1} \mathbb{I}_{X_i\leq x}, x\in \mathbb{R}
# $$
# Para $x \in \mathbb{R}$ fijo, mostrar que $\mathbb{E}[F_n(x)]=F(x)$ y $Var[F_n(x)]= \frac{F(x)(1-F(x))}{n}$.

# %%
import pandas as np
print("prueba")
# Out:
# prueba
